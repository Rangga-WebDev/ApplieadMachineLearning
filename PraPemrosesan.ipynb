# %%
import pandas as pd
import numpy as np

df = pd.read_excel('Asuransi.xlsx')

bin = [0, 18.5, 24.9, 29.9, 100]
label = ['Underweight', 'Normal', 'Overweight', 'Obese']

df['bmi_class'] = pd.cut(df['bmi'], bins=bin, labels=label)

print(df[['bmi', 'bmi_class']].head())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 9
#       6 bin = [0, 18.5, 24.9, 29.9, 100]
#       7 label = ['Underweight', 'Normal', 'Overweight', 'Obese']
# ----> 9 df['bmi_class'] = pd.cut(df['bmi'], bin=bin, label=label)
#      11 print(df[['bmi', 'bmi_class']].head())
#
# TypeError: cut() got an unexpected keyword argument 'bin'
